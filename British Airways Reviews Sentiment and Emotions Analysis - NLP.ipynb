# %% [markdown]
# # British Airways Reviews Sentiment + Emotions Analysis
#
# ---
#
# ## Web Scraping
#
# This Jupyter notebook includes some code to get you started with web scraping. We will use a package called `BeautifulSoup` to collect the data from the web. Once you've collected your data and saved it into a local `.csv` file you should start with your analysis.
#
# ### Scraping data from Skytrax and Trustpilot
#
# If you visit [https://www.airlinequality.com], [https://www.trustpilot.com] you can see that there is a lot of data there. For this task, we are only interested in reviews related to British and the Airline itself.
#
# If you navigate to this links: [https://www.airlinequality.com/airline-reviews/british-airways], [https://www.trustpilot.com/review/www.britishairways.com] you will see this data. Now, we can use `Python` and `BeautifulSoup` to collect all the links to the reviews and then to collect the text data on each of the individual review links.

# %%
# import needed packages
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#---------------------- skytrax section --------------------------------

base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 34            # number of pages 
page_size = 100      

reviews = []        # 100*22 = 2200 review  

# for i in range(1, pages + 1) to iterate over the pages
for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
    
    print(f" Skytrax ---> {len(reviews)} total reviews")

print(f"------------------------Scraping for Skytrax Finished ---> {len(reviews)} total reviews------------------------------")
# Out:
# Scraping page 1
#  Skytrax ---> 100 total reviews
# Scraping page 2
#  Skytrax ---> 200 total reviews
# Scraping page 3
#  Skytrax ---> 300 total reviews
# Scraping page 4
#  Skytrax ---> 400 total reviews
# Scraping page 5
#  Skytrax ---> 500 total reviews
# Scraping page 6
#  Skytrax ---> 600 total reviews
# Scraping page 7
#  Skytrax ---> 700 total reviews
# Scraping page 8
#  Skytrax ---> 800 total reviews
# Scraping page 9
#  Skytrax ---> 900 total reviews
# Scraping page 10
#  Skytrax ---> 1000 total reviews
# Scraping page 11
#  Skytrax ---> 1100 total reviews
# Scraping page 12
#  Skytrax ---> 1200 total reviews
# Scraping page 13
#  Skytrax ---> 1300 total reviews
# Scraping page 14
#  Skytrax ---> 1400 total reviews
# Scraping page 15
#  Skytrax ---> 1500 total reviews
# Scraping page 16
#  Skytrax ---> 1600 total reviews
# Scraping page 17
#  Skytrax ---> 1700 total reviews
# Scraping page 18
#  Skytrax ---> 1800 total reviews
# Scraping page 19
#  Skytrax ---> 1900 total reviews
# Scraping page 20
#  Skytrax ---> 2000 total reviews
# Scraping page 21
#  Skytrax ---> 2100 total reviews
# Scraping page 22
#  Skytrax ---> 2200 total reviews
# Scraping page 23
#  Skytrax ---> 2300 total reviews
# Scraping page 24
#  Skytrax ---> 2400 total reviews
# Scraping page 25
#  Skytrax ---> 2500 total reviews
# Scraping page 26
#  Skytrax ---> 2600 total reviews
# Scraping page 27
#  Skytrax ---> 2700 total reviews
# Scraping page 28
#  Skytrax ---> 2800 total reviews
# Scraping page 29
#  Skytrax ---> 2900 total reviews
# Scraping page 30
#  Skytrax ---> 3000 total reviews
# Scraping page 31
#  Skytrax ---> 3100 total reviews
# Scraping page 32
#  Skytrax ---> 3200 total reviews
# Scraping page 33
#  Skytrax ---> 3300 total reviews
# Scraping page 34
#  Skytrax ---> 3400 total reviews
# ------------------------Scraping for Skytrax Finished ---> 3400 total reviews------------------------------

# %%
pages = 312  # number of pages 
pilot_reviews = []

# for i in range(1, pages + 1) to iterate over the pages
for i in range(1, pages + 1):
    
    # Create URL to collect links from paginated data
    url = f"https://www.trustpilot.com/review/www.britishairways.com?page={i}&sort=recency"

    print(f"Scraping page {i}")

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("p", {"class": "typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn"}):
        pilot_reviews.append(para.get_text())
    

    print(f"TrustPilot---> {len(pilot_reviews)} total reviews")
# Out:
# Scraping page 1
# TrustPilot---> 20 total reviews
# Scraping page 2
# TrustPilot---> 40 total reviews
# Scraping page 3
# TrustPilot---> 60 total reviews
# Scraping page 4
# TrustPilot---> 80 total reviews
# Scraping page 5
# TrustPilot---> 100 total reviews
# Scraping page 6
# TrustPilot---> 120 total reviews
# Scraping page 7
# TrustPilot---> 140 total reviews
# Scraping page 8
# TrustPilot---> 160 total reviews
# Scraping page 9
# TrustPilot---> 180 total reviews
# Scraping page 10
# TrustPilot---> 200 total reviews
# Scraping page 11
# TrustPilot---> 220 total reviews
# Scraping page 12
# TrustPilot---> 240 total reviews
# Scraping page 13
# TrustPilot---> 260 total reviews
# Scraping page 14
# TrustPilot---> 279 total reviews
# Scraping page 15
# TrustPilot---> 299 total reviews
# Scraping page 16
# TrustPilot---> 319 total reviews
# Scraping page 17
# TrustPilot---> 339 total reviews
# Scraping page 18
# TrustPilot---> 358 total reviews
# Scraping page 19
# TrustPilot---> 378 total reviews
# Scraping page 20
# TrustPilot---> 398 total reviews
# Scraping page 21
# TrustPilot---> 418 total reviews
# Scraping page 22
# TrustPilot---> 438 total reviews
# Scraping page 23
# TrustPilot---> 458 total reviews
# Scraping page 24
# TrustPilot---> 478 total reviews
# Scraping page 25
# TrustPilot---> 498 total reviews
# Scraping page 26
# TrustPilot---> 518 total reviews
# Scraping page 27
# TrustPilot---> 537 total reviews
# Scraping page 28
# TrustPilot---> 557 total reviews
# Scraping page 29
# TrustPilot---> 577 total reviews
# Scraping page 30
# TrustPilot---> 597 total reviews
# Scraping page 31
# TrustPilot---> 617 total reviews
# Scraping page 32
# TrustPilot---> 637 total reviews
# Scraping page 33
# TrustPilot---> 657 total reviews
# Scraping page 34
# TrustPilot---> 677 total reviews
# Scraping page 35
# TrustPilot---> 697 total reviews
# Scraping page 36
# TrustPilot---> 717 total reviews
# Scraping page 37
# TrustPilot---> 737 total reviews
# Scraping page 38
# TrustPilot---> 757 total reviews
# Scraping page 39
# TrustPilot---> 777 total reviews
# Scraping page 40
# TrustPilot---> 797 total reviews
# Scraping page 41
# TrustPilot---> 817 total reviews
# Scraping page 42
# TrustPilot---> 836 total reviews
# Scraping page 43
# TrustPilot---> 856 total reviews
# Scraping page 44
# TrustPilot---> 875 total reviews
# Scraping page 45
# TrustPilot---> 895 total reviews
# Scraping page 46
# TrustPilot---> 915 total reviews
# Scraping page 47
# TrustPilot---> 935 total reviews
# Scraping page 48
# TrustPilot---> 954 total reviews
# Scraping page 49
# TrustPilot---> 974 total reviews
# Scraping page 50
# TrustPilot---> 994 total reviews
# Scraping page 51
# TrustPilot---> 1014 total reviews
# Scraping page 52
# TrustPilot---> 1034 total reviews
# Scraping page 53
# TrustPilot---> 1054 total reviews
# Scraping page 54
# TrustPilot---> 1074 total reviews
# Scraping page 55
# TrustPilot---> 1094 total reviews
# Scraping page 56
# TrustPilot---> 1114 total reviews
# Scraping page 57
# TrustPilot---> 1134 total reviews
# Scraping page 58
# TrustPilot---> 1154 total reviews
# Scraping page 59
# TrustPilot---> 1172 total reviews
# Scraping page 60
# TrustPilot---> 1192 total reviews
# Scraping page 61
# TrustPilot---> 1212 total reviews
# Scraping page 62
# TrustPilot---> 1232 total reviews
# Scraping page 63
# TrustPilot---> 1252 total reviews
# Scraping page 64
# TrustPilot---> 1271 total reviews
# Scraping page 65
# TrustPilot---> 1290 total reviews
# Scraping page 66
# TrustPilot---> 1310 total reviews
# Scraping page 67
# TrustPilot---> 1330 total reviews
# Scraping page 68
# TrustPilot---> 1350 total reviews
# Scraping page 69
# TrustPilot---> 1369 total reviews
# Scraping page 70
# TrustPilot---> 1389 total reviews
# Scraping page 71
# TrustPilot---> 1409 total reviews
# Scraping page 72
# TrustPilot---> 1429 total reviews
# Scraping page 73
# TrustPilot---> 1449 total reviews
# Scraping page 74
# TrustPilot---> 1469 total reviews
# Scraping page 75
# TrustPilot---> 1489 total reviews
# Scraping page 76
# TrustPilot---> 1509 total reviews
# Scraping page 77
# TrustPilot---> 1529 total reviews
# Scraping page 78
# TrustPilot---> 1548 total reviews
# Scraping page 79
# TrustPilot---> 1568 total reviews
# Scraping page 80
# TrustPilot---> 1588 total reviews
# Scraping page 81
# TrustPilot---> 1608 total reviews
# Scraping page 82
# TrustPilot---> 1628 total reviews
# Scraping page 83
# TrustPilot---> 1648 total reviews
# Scraping page 84
# TrustPilot---> 1668 total reviews
# Scraping page 85
# TrustPilot---> 1688 total reviews
# Scraping page 86
# TrustPilot---> 1707 total reviews
# Scraping page 87
# TrustPilot---> 1726 total reviews
# Scraping page 88
# TrustPilot---> 1746 total reviews
# Scraping page 89
# TrustPilot---> 1766 total reviews
# Scraping page 90
# TrustPilot---> 1786 total reviews
# Scraping page 91
# TrustPilot---> 1805 total reviews
# Scraping page 92
# TrustPilot---> 1825 total reviews
# Scraping page 93
# TrustPilot---> 1845 total reviews
# Scraping page 94
# TrustPilot---> 1865 total reviews
# Scraping page 95
# TrustPilot---> 1885 total reviews
# Scraping page 96
# TrustPilot---> 1905 total reviews
# Scraping page 97
# TrustPilot---> 1925 total reviews
# Scraping page 98
# TrustPilot---> 1945 total reviews
# Scraping page 99
# TrustPilot---> 1965 total reviews
# Scraping page 100
# TrustPilot---> 1985 total reviews
# Scraping page 101
# TrustPilot---> 2004 total reviews
# Scraping page 102
# TrustPilot---> 2024 total reviews
# Scraping page 103
# TrustPilot---> 2044 total reviews
# Scraping page 104
# TrustPilot---> 2064 total reviews
# Scraping page 105
# TrustPilot---> 2084 total reviews
# Scraping page 106
# TrustPilot---> 2104 total reviews
# Scraping page 107
# TrustPilot---> 2124 total reviews
# Scraping page 108
# TrustPilot---> 2144 total reviews
# Scraping page 109
# TrustPilot---> 2163 total reviews
# Scraping page 110
# TrustPilot---> 2183 total reviews
# Scraping page 111
# TrustPilot---> 2203 total reviews
# Scraping page 112
# TrustPilot---> 2223 total reviews
# Scraping page 113
# TrustPilot---> 2243 total reviews
# Scraping page 114
# TrustPilot---> 2263 total reviews
# Scraping page 115
# TrustPilot---> 2283 total reviews
# Scraping page 116
# TrustPilot---> 2303 total reviews
# Scraping page 117
# TrustPilot---> 2323 total reviews
# Scraping page 118
# TrustPilot---> 2341 total reviews
# Scraping page 119
# TrustPilot---> 2361 total reviews
# Scraping page 120
# TrustPilot---> 2380 total reviews
# Scraping page 121
# TrustPilot---> 2400 total reviews
# Scraping page 122
# TrustPilot---> 2420 total reviews
# Scraping page 123
# TrustPilot---> 2440 total reviews
# Scraping page 124
# TrustPilot---> 2460 total reviews
# Scraping page 125
# TrustPilot---> 2480 total reviews
# Scraping page 126
# TrustPilot---> 2499 total reviews
# Scraping page 127
# TrustPilot---> 2519 total reviews
# Scraping page 128
# TrustPilot---> 2539 total reviews
# Scraping page 129
# TrustPilot---> 2559 total reviews
# Scraping page 130
# TrustPilot---> 2579 total reviews
# Scraping page 131
# TrustPilot---> 2598 total reviews
# Scraping page 132
# TrustPilot---> 2618 total reviews
# Scraping page 133
# TrustPilot---> 2638 total reviews
# Scraping page 134
# TrustPilot---> 2658 total reviews
# Scraping page 135
# TrustPilot---> 2678 total reviews
# Scraping page 136
# TrustPilot---> 2698 total reviews
# Scraping page 137
# TrustPilot---> 2718 total reviews
# Scraping page 138
# TrustPilot---> 2738 total reviews
# Scraping page 139
# TrustPilot---> 2758 total reviews
# Scraping page 140
# TrustPilot---> 2778 total reviews
# Scraping page 141
# TrustPilot---> 2797 total reviews
# Scraping page 142
# TrustPilot---> 2817 total reviews
# Scraping page 143
# TrustPilot---> 2837 total reviews
# Scraping page 144
# TrustPilot---> 2857 total reviews
# Scraping page 145
# TrustPilot---> 2877 total reviews
# Scraping page 146
# TrustPilot---> 2896 total reviews
# Scraping page 147
# TrustPilot---> 2916 total reviews
# Scraping page 148
# TrustPilot---> 2936 total reviews
# Scraping page 149
# TrustPilot---> 2956 total reviews
# Scraping page 150
# TrustPilot---> 2976 total reviews
# Scraping page 151
# TrustPilot---> 2995 total reviews
# Scraping page 152
# TrustPilot---> 3015 total reviews
# Scraping page 153
# TrustPilot---> 3034 total reviews
# Scraping page 154
# TrustPilot---> 3053 total reviews
# Scraping page 155
# TrustPilot---> 3072 total reviews
# Scraping page 156
# TrustPilot---> 3092 total reviews
# Scraping page 157
# TrustPilot---> 3112 total reviews
# Scraping page 158
# TrustPilot---> 3132 total reviews
# Scraping page 159
# TrustPilot---> 3151 total reviews
# Scraping page 160
# TrustPilot---> 3171 total reviews
# Scraping page 161
# TrustPilot---> 3191 total reviews
# Scraping page 162
# TrustPilot---> 3210 total reviews
# Scraping page 163
# TrustPilot---> 3230 total reviews
# Scraping page 164
# TrustPilot---> 3250 total reviews
# Scraping page 165
# TrustPilot---> 3270 total reviews
# Scraping page 166
# TrustPilot---> 3289 total reviews
# Scraping page 167
# TrustPilot---> 3309 total reviews
# Scraping page 168
# TrustPilot---> 3329 total reviews
# Scraping page 169
# TrustPilot---> 3349 total reviews
# Scraping page 170
# TrustPilot---> 3369 total reviews
# Scraping page 171
# TrustPilot---> 3389 total reviews
# Scraping page 172
# TrustPilot---> 3408 total reviews
# Scraping page 173
# TrustPilot---> 3428 total reviews
# Scraping page 174
# TrustPilot---> 3448 total reviews
# Scraping page 175
# TrustPilot---> 3468 total reviews
# Scraping page 176
# TrustPilot---> 3488 total reviews
# Scraping page 177
# TrustPilot---> 3508 total reviews
# Scraping page 178
# TrustPilot---> 3528 total reviews
# Scraping page 179
# TrustPilot---> 3548 total reviews
# Scraping page 180
# TrustPilot---> 3568 total reviews
# Scraping page 181
# TrustPilot---> 3588 total reviews
# Scraping page 182
# TrustPilot---> 3608 total reviews
# Scraping page 183
# TrustPilot---> 3628 total reviews
# Scraping page 184
# TrustPilot---> 3648 total reviews
# Scraping page 185
# TrustPilot---> 3668 total reviews
# Scraping page 186
# TrustPilot---> 3688 total reviews
# Scraping page 187
# TrustPilot---> 3708 total reviews
# Scraping page 188
# TrustPilot---> 3728 total reviews
# Scraping page 189
# TrustPilot---> 3748 total reviews
# Scraping page 190
# TrustPilot---> 3768 total reviews
# Scraping page 191
# TrustPilot---> 3788 total reviews
# Scraping page 192
# TrustPilot---> 3808 total reviews
# Scraping page 193
# TrustPilot---> 3828 total reviews
# Scraping page 194
# TrustPilot---> 3848 total reviews
# Scraping page 195
# TrustPilot---> 3868 total reviews
# Scraping page 196
# TrustPilot---> 3888 total reviews
# Scraping page 197
# TrustPilot---> 3908 total reviews
# Scraping page 198
# TrustPilot---> 3928 total reviews
# Scraping page 199
# TrustPilot---> 3948 total reviews
# Scraping page 200
# TrustPilot---> 3968 total reviews
# Scraping page 201
# TrustPilot---> 3988 total reviews
# Scraping page 202
# TrustPilot---> 4008 total reviews
# Scraping page 203
# TrustPilot---> 4028 total reviews
# Scraping page 204
# TrustPilot---> 4048 total reviews
# Scraping page 205
# TrustPilot---> 4068 total reviews
# Scraping page 206
# TrustPilot---> 4087 total reviews
# Scraping page 207
# TrustPilot---> 4107 total reviews
# Scraping page 208
# TrustPilot---> 4127 total reviews
# Scraping page 209
# TrustPilot---> 4147 total reviews
# Scraping page 210
# TrustPilot---> 4167 total reviews
# Scraping page 211
# TrustPilot---> 4187 total reviews
# Scraping page 212
# TrustPilot---> 4207 total reviews
# Scraping page 213
# TrustPilot---> 4227 total reviews
# Scraping page 214
# TrustPilot---> 4247 total reviews
# Scraping page 215
# TrustPilot---> 4267 total reviews
# Scraping page 216
# TrustPilot---> 4287 total reviews
# Scraping page 217
# TrustPilot---> 4307 total reviews
# Scraping page 218
# TrustPilot---> 4327 total reviews
# Scraping page 219
# TrustPilot---> 4347 total reviews
# Scraping page 220
# TrustPilot---> 4367 total reviews
# Scraping page 221
# TrustPilot---> 4387 total reviews
# Scraping page 222
# TrustPilot---> 4407 total reviews
# Scraping page 223
# TrustPilot---> 4427 total reviews
# Scraping page 224
# TrustPilot---> 4447 total reviews
# Scraping page 225
# TrustPilot---> 4467 total reviews
# Scraping page 226
# TrustPilot---> 4487 total reviews
# Scraping page 227
# TrustPilot---> 4507 total reviews
# Scraping page 228
# TrustPilot---> 4526 total reviews
# Scraping page 229
# TrustPilot---> 4546 total reviews
# Scraping page 230
# TrustPilot---> 4566 total reviews
# Scraping page 231
# TrustPilot---> 4586 total reviews
# Scraping page 232
# TrustPilot---> 4606 total reviews
# Scraping page 233
# TrustPilot---> 4626 total reviews
# Scraping page 234
# TrustPilot---> 4646 total reviews
# Scraping page 235
# TrustPilot---> 4665 total reviews
# Scraping page 236
# TrustPilot---> 4685 total reviews
# Scraping page 237
# TrustPilot---> 4704 total reviews
# Scraping page 238
# TrustPilot---> 4723 total reviews
# Scraping page 239
# TrustPilot---> 4743 total reviews
# Scraping page 240
# TrustPilot---> 4763 total reviews
# Scraping page 241
# TrustPilot---> 4783 total reviews
# Scraping page 242
# TrustPilot---> 4803 total reviews
# Scraping page 243
# TrustPilot---> 4823 total reviews
# Scraping page 244
# TrustPilot---> 4843 total reviews
# Scraping page 245
# TrustPilot---> 4863 total reviews
# Scraping page 246
# TrustPilot---> 4883 total reviews
# Scraping page 247
# TrustPilot---> 4903 total reviews
# Scraping page 248
# TrustPilot---> 4923 total reviews
# Scraping page 249
# TrustPilot---> 4943 total reviews
# Scraping page 250
# TrustPilot---> 4963 total reviews
# Scraping page 251
# TrustPilot---> 4983 total reviews
# Scraping page 252
# TrustPilot---> 5003 total reviews
# Scraping page 253
# TrustPilot---> 5022 total reviews
# Scraping page 254
# TrustPilot---> 5042 total reviews
# Scraping page 255
# TrustPilot---> 5062 total reviews
# Scraping page 256
# TrustPilot---> 5082 total reviews
# Scraping page 257
# TrustPilot---> 5102 total reviews
# Scraping page 258
# TrustPilot---> 5122 total reviews
# Scraping page 259
# TrustPilot---> 5142 total reviews
# Scraping page 260
# TrustPilot---> 5162 total reviews
# Scraping page 261
# TrustPilot---> 5182 total reviews
# Scraping page 262
# TrustPilot---> 5201 total reviews
# Scraping page 263
# TrustPilot---> 5221 total reviews
# Scraping page 264
# TrustPilot---> 5241 total reviews
# Scraping page 265
# TrustPilot---> 5261 total reviews
# Scraping page 266
# TrustPilot---> 5281 total reviews
# Scraping page 267
# TrustPilot---> 5301 total reviews
# Scraping page 268
# TrustPilot---> 5321 total reviews
# Scraping page 269
# TrustPilot---> 5341 total reviews
# Scraping page 270
# TrustPilot---> 5360 total reviews
# Scraping page 271
# TrustPilot---> 5380 total reviews
# Scraping page 272
# TrustPilot---> 5400 total reviews
# Scraping page 273
# TrustPilot---> 5420 total reviews
# Scraping page 274
# TrustPilot---> 5440 total reviews
# Scraping page 275
# TrustPilot---> 5460 total reviews
# Scraping page 276
# TrustPilot---> 5480 total reviews
# Scraping page 277
# TrustPilot---> 5499 total reviews
# Scraping page 278
# TrustPilot---> 5519 total reviews
# Scraping page 279
# TrustPilot---> 5539 total reviews
# Scraping page 280
# TrustPilot---> 5558 total reviews
# Scraping page 281
# TrustPilot---> 5578 total reviews
# Scraping page 282
# TrustPilot---> 5598 total reviews
# Scraping page 283
# TrustPilot---> 5618 total reviews
# Scraping page 284
# TrustPilot---> 5638 total reviews
# Scraping page 285
# TrustPilot---> 5658 total reviews
# Scraping page 286
# TrustPilot---> 5678 total reviews
# Scraping page 287
# TrustPilot---> 5698 total reviews
# Scraping page 288
# TrustPilot---> 5718 total reviews
# Scraping page 289
# TrustPilot---> 5738 total reviews
# Scraping page 290
# TrustPilot---> 5758 total reviews
# Scraping page 291
# TrustPilot---> 5778 total reviews
# Scraping page 292
# TrustPilot---> 5798 total reviews
# Scraping page 293
# TrustPilot---> 5818 total reviews
# Scraping page 294
# TrustPilot---> 5838 total reviews
# Scraping page 295
# TrustPilot---> 5858 total reviews
# Scraping page 296
# TrustPilot---> 5878 total reviews
# Scraping page 297
# TrustPilot---> 5898 total reviews
# Scraping page 298
# TrustPilot---> 5918 total reviews
# Scraping page 299
# TrustPilot---> 5938 total reviews
# Scraping page 300
# TrustPilot---> 5958 total reviews
# Scraping page 301
# TrustPilot---> 5978 total reviews
# Scraping page 302
# TrustPilot---> 5998 total reviews
# Scraping page 303
# TrustPilot---> 6018 total reviews
# Scraping page 304
# TrustPilot---> 6038 total reviews
# Scraping page 305
# TrustPilot---> 6057 total reviews
# Scraping page 306
# TrustPilot---> 6077 total reviews
# Scraping page 307
# TrustPilot---> 6097 total reviews
# Scraping page 308
# TrustPilot---> 6117 total reviews
# Scraping page 309
# TrustPilot---> 6117 total reviews
# Scraping page 310
# TrustPilot---> 6117 total reviews
# Scraping page 311
# TrustPilot---> 6137 total reviews
# Scraping page 312
# TrustPilot---> 6145 total reviews

# %% [markdown]
# ## Turn extracted data into csv files

# %%
df_st = pd.DataFrame()
df_st["reviews"] = reviews
df_st.to_csv("British_reviews_skytrax.csv")

df_tp = pd.DataFrame()
df_tp["reviews"] = pilot_reviews
df_tp.to_csv("British_reviews_trustpilot.csv")

# %% [markdown]
# ## Read and load csv file

# %%
#read the csv file for British Airways reviews from skyrax and take a look 
df_st = pd.read_csv("British_reviews_skytrax.csv", index_col= 0)
df_st.head()
# Out:
#                                              reviews
# 0  ✅ Trip Verified |  I was flying to Warsaw for ...
# 1  ✅ Trip Verified |  Booked a BA holiday to Marr...
# 2  ✅ Trip Verified | Extremely sub-par service. H...
# 3  ✅ Trip Verified |  I virtually gave up on Brit...
# 4  ✅ Trip Verified |  I was pleasantly surprised ...

# %%
#read the csv file for British Airways reviews from trustpilot and take a look 
df_tp = pd.read_csv("British_reviews_trustpilot.csv", index_col= 0)
df_tp.head()
# Out:
#                                              reviews
# 0  British airways...what a shower of s**t our na...
# 1  Flew from Heathrow to Jo'burg. Meet and greet ...
# 2  Flight from Manchester via Heathrow to JFK ret...
# 3  Flight from Heathrow to Cape Town 18thNovember...
# 4  Awful customer service. Tried calling to get c...

# %% [markdown]
# ##  Now let's clean the text data
# #### plus u have to make sure there are:
# 1. No useless text data.
# 2. No Uppercase letters (turn all letters to lowercase).
# 3. No Punctuations.
# 4. Tokenization and stop words handling.

# %%
import string   # we need it for Punctuations removal
from stop_words import get_stop_words   # or we can use from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize # it turn text to list but more faster 

def sentiment_clean_text(text):
    '''
    this function take text and clean it  

    Parameters
    ----------
    text : string 

    Returns
    -------
    text_list : string after cleaning.

    '''


    # A. first step remove useless text data (if there are any) note: i don't need data before | so I will remove it 
    if '|' in text:
        text =  text.split('|')[1]   
       
    # B. second turn letters into lowercase 
    text = text.lower()
        
    # C. third remove all Punctuations.
    text = text.translate(str.maketrans('','',string.punctuation))
    
    return text

def emotion_clean_text(text):
    '''
    this function take text and clean it then turn it to list of words 

    Parameters
    ----------
    text : string 

    Returns
    -------
    text_list : list of text words after cleaning.

    '''
        
    # D. forth step Tokenization and stop words 
        
    # Tokenizaiton: turning string into list of words.
    # Stop words: words without meaning for sentiment analysis.

        
    # Tokenizaiton
    text = word_tokenize(text,"english")
    
    # handeling the stop words but what are the stop words 
    stop_words = get_stop_words('english') #or we can use stop_words = stopwords.words('english')

    # Removing stop words from the tokenized words list
    text_list = []
    
    for word in text:
        if word not in stop_words:
            text_list.append(word)

       
    # return the list of words
    return text_list

# %% [markdown]
# ## Emotion text dectionary

# %%
def emotion_maping (file,di): 
    
    for line in file:
        clear_line = line.replace("\n", '').replace(",", '').replace("'", '').strip()
        word, emotion = clear_line.split(':')
        di[word] = emotion
            
    return di

# %% [markdown]
# ## Now we have clean data let's Do sentiment analysis

# %%
# let's import the needed packages 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# function to carry out the     
def sentiment_analyze(text):
    
    scores = SentimentIntensityAnalyzer().polarity_scores(text) # return dictionary of scores
    
    if (scores['neg'] > scores['pos']):
        return 0
    
    else:
        return 1

# %% [markdown]
# ## Main

# %%
from collections import Counter

# define needed data structures
cleaned_text = ""
temp_emotion_list = []
score = 0
emotion_dict = {}
words_score_dict = {}
moods_list_st = []
moods_list_tp = []

# get the emotion dictionary ready
emotion_file = open('emotions.txt','r',encoding='utf-8') 
emotion_dict = emotion_maping(emotion_file,emotion_dict)
emotion_file.close()

# ------------------------ loop for the skytrx Dataframe ------------------------------

# loop for all reviews in Skytrax dataFrame  
for i in range(len(df_st)):
    
    # get the review of index i
    text = str(df_st['reviews'][i])
    
    # step 1: let's clean the text and assign cleaned list to dataFrame 
    # simple clean 
    cleaned_text= sentiment_clean_text(text)
    
    #Step 2: sentiment Analysis
    score = sentiment_analyze(cleaned_text)
    moods_list_st.append(score)

    
    # Step 3: advanced clean for emotions
    cleaned_text_list = emotion_clean_text(cleaned_text)
    df_st['reviews'][i] = cleaned_text_list
    

    # Step 4: emotion list builder
    for word in emotion_dict.keys():
        if word in cleaned_text_list:
            temp_emotion_list.append(emotion_dict[word])    

# now let's create new column for moods for skytrax
df_st['mood'] = moods_list_st


# ------------------------ loop for the trustpilot Dataframe ------------------------------

# loop for all reviews in trustpilot dataFrame  
for i in range(len(df_tp)):
    
    # get the review of index i
    text = str(df_tp['reviews'][i])
    
    # step 1: let's clean the text and assign cleaned list to dataFrame 
    # simple clean 
    cleaned_text= sentiment_clean_text(text)
    
    #Step 2: sentiment Analysis
    score = sentiment_analyze(cleaned_text)
    moods_list_tp.append(score)

    
    # Step 3: advanced clean for emotions
    cleaned_text_list = emotion_clean_text(cleaned_text)
    df_tp['reviews'][i] = cleaned_text_list
    

    # Step 4: emotion list builder
    for word in emotion_dict.keys():
        if word in cleaned_text_list:
            temp_emotion_list.append(emotion_dict[word])  


# now let's create new column for moods trust pilot dataframe
df_tp['mood'] = moods_list_tp

# %% [markdown]
# ## Plot  findings

# %%
#____________________________ Plot for sentiment Vader scores ____________________________________


# Step 5: plot sentiment and emotions 
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')


# get summary dictionary for sentiment 
moods_list_all = moods_list_st + moods_list_tp
mmod_summary = dict(Counter(moods_list_all))

# rename dictionary keys before ploting 
mmod_summary['positive'] = mmod_summary.pop(1)
mmod_summary['negative'] = mmod_summary.pop(0)

fig, ax = plt.subplots()
ax.bar(mmod_summary.keys(), mmod_summary.values())

# label the plot 
plt.xlabel('Sentiments')
plt.ylabel('Frequency')
plt.savefig('Sentiments.png')
plt.show()

# %%
#____________________________ Plot for emotions ____________________________________

# turn the emotion list into dictionary 
words_score_dict = dict(Counter(temp_emotion_list))

# now let's go more Specifically and just choose emotions with freq more than 10
more_than_15_emotions = dict( (key, value) for (key, value) in words_score_dict.items() if value > 15 )


fig, ax = plt.subplots()
#ax.bar(words_score_dict.keys(), words_score_dict.values())
ax.bar(more_than_15_emotions.keys(), more_than_15_emotions.values())

# the fit the text undre graph 
fig.autofmt_xdate()

# change the width and length of plot 
fig.set_figwidth(20)
fig.set_figheight(10)

# label the plot 
plt.xlabel('Emotions')
plt.ylabel('Frequency')

#save the graph and show it 
plt.savefig('More_than_15_emotions.png')
plt.show()

# %% [markdown]
# ## The End, hope u enjoyed 😊❤️
